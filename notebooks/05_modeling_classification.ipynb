# %%
# !pip install pandas pyarrow gcsfs

# %%
import pandas as pd

# La ruta exacta según tu imagen
path = "gs://emotor-dataset-processed/df_ml_global.parquet"

# Leer el archivo directamente desde Google Cloud Storage
df = pd.read_parquet(path)

# Visualizar los primeros datos
print(df.head())
# Out:
#    current_u_mean  current_u_std  current_u_rms  current_u_kurtosis  \
# 0        0.051824       2.369356       2.369923           -1.534883
# 1        0.129027       2.339341       2.342897           -1.496389
# 2        0.170414       2.279735       2.286095           -1.453073
# 3        0.183585       2.274952       2.282347           -1.451941
# 4        0.136873       2.332955       2.336966           -1.498397
#
#    current_u_skew  current_v_mean  current_v_std  current_v_rms  \
# 0        0.007640       -0.256863       2.293489       2.307829
# 1       -0.076224       -0.273917       2.266691       2.283182
# 2       -0.088774       -0.201464       2.310442       2.319209
# 3       -0.093499       -0.093555       2.360467       2.362321
# 4       -0.081313        0.005902       2.344801       2.344808
#
#    current_v_kurtosis  current_v_skew  ...  vib_x_B_spec_energy_high  \
# 0           -1.434533        0.103552  ...              1.782923e+06
# ...
